# %%
import sys
sys.path.append("./utils/")
import torch
from torchvision import datasets
from torchvision import transforms
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import torch.nn.utils.prune as prune
import utils.util as util

# %% [markdown]
# ### Hyperparameters

# %%
batch_size = 100
hidden_size = 256
hidden_level = 4
lr = 0.001 
epochs = 50
momentum = 0.9

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Load Dataset

# %%
training_data = datasets.MNIST("./data", train=True, transform=transforms.ToTensor(), download=True)
test_data = datasets.MNIST("./data", train=False, transform=transforms.ToTensor(), download=True)

training_loader = torch.utils.data.DataLoader(dataset=training_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

# Images have same size
input_size = np.prod(training_data[0][0].shape[1:])
output_size = 10

# %% [markdown]
# ### Network

# %%
class MnistNetwork(torch.nn.Module):

    def __init__(self, input_size, output_size, hidden_size, device="cpu"):

        self.output_size = output_size
        self.hidden_size = hidden_size
        self.device = device

        super(MnistNetwork, self).__init__()

        self.l1 = torch.nn.Linear(input_size, hidden_size, bias=False, device=device)
        self.a1 = torch.nn.ReLU()

        self.l2 = torch.nn.Linear(hidden_size, hidden_size, bias=False, device=device)
        self.a2 = torch.nn.ReLU()

        self.l3 = torch.nn.Linear(hidden_size, hidden_size, bias=False, device=device)
        self.a3 = torch.nn.ReLU()

        self.l4 = torch.nn.Linear(hidden_size, hidden_size, bias=False, device=device)
        self.a4 = torch.nn.ReLU()

        self.l5 = torch.nn.Linear(hidden_size, output_size, bias=False, device=device)
        self.a5 = torch.nn.ReLU()
    
    def forward(self, x):

        out = self.l1(x)
        out = self.a1(out)

        out = self.l2(out)
        out = self.a2(out)

        out = self.l3(out)
        out = self.a3(out)

        out = self.l4(out)
        out = self.a4(out)

        out = self.l5(out)
        out = self.a5(out)

        return out

    def trainModel(self, training_loader, test_loader, epochs=100, lr=0.01, writer = None, PATH = None):

        loss_function = torch.nn.CrossEntropyLoss()
        optimizer = torch.optim.SGD(model.parameters(), momentum=momentum, lr=lr)

        util.train(model=self, 
            training_loader=training_loader, 
            test_loader=test_loader, 
            loss_function=loss_function, 
            optimizer=optimizer, 
            epochs=epochs, 
            lr=lr, 
            dim=1, 
            device=self.device, 
            writer=writer, 
            PATH=PATH)

model = MnistNetwork(input_size, output_size, hidden_size, device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 62
#      48         optimizer = torch.optim.SGD(model.parameters(), momentum=momentum, lr=lr)
#      50         util.train(model=self,
#      51             training_loader=training_loader,
#      52             test_loader=test_loader,
#    (...)
#      59             writer=writer,
#      60             PATH=PATH)
# ---> 62 model = MnistNetwork(input_size, output_size, hidden_size, device)
#
# NameError: name 'input_size' is not defined

# %% [markdown]
# ### Training modello

# %%
writer = SummaryWriter("./test_grafici/MnistNetwork")
PATH = "./models/MnistNetwork_model"
model.trainModel(training_loader, test_loader, epochs, 0.1, writer, PATH)

# %% [markdown]
# ### Load Model

# %%
util.load_model(model, "./models/MnistNetwork_model")
util.getAccuracy(model, test_loader, device)

# %% [markdown]
# ### Binarizzazione modello

# %%
import utils.binarizedModel as bModel
bmodel = bModel.MNISTBinarizedModel(model, device)

# %% [markdown]
# #### Training modello binarizzato

# %%
writer = SummaryWriter("./test_grafici/MnistNetworkBinarized")
PATH = "./models/MnistNetwork_binarized_model" 
bmodel.trainModel(training_loader, test_loader, epochs, 0.01, writer=writer, PATH=PATH)

# %% [markdown]
# #### Load modello binarizzato

# %%
util.load_model(bmodel, "./models/MnistNetwork_binarized_model")
bmodel.getAccuracy(test_loader)

# %% [markdown]
# ### Pruning del modello binarizzato

# %% [markdown]
# Preparazione dei dati

# %%
import utils.binarizedModel as bModel
model = MnistNetwork(input_size, output_size, hidden_size, device)
util.load_model(model, "./models/MnistNetworkPruned_model")
bmodel = bModel.MNISTBinarizedModel(model, device)
util.load_model(bmodel, "./models/MnistNetwork_binarized_model")
util.save_model(bmodel, "./models/MnistNetworkPruned_binarized_model_wp")

# %% [markdown]
# Training del modello binarizzato. Il primo parametro è il threshold. Si utilizza prune poiché viene usata la binarizzazione -1 0 1.

# %%
bmodel.prune(5, training_loader, test_loader, epochs, 0.01, None, "./models/MnistNetworkPruned_binarized_model_wp")

# %% [markdown]
# Pruning. Settare la lettura del modello _wp per effettuare il puning.

# %%
util.load_model(bmodel, "./models/MnistNetworkPruned_binarized_model_wp")
parameters_to_prune = ((bmodel.fcLayers[0], "weight"), (bmodel.fcLayers[1], "weight"), (bmodel.fcLayers[2], "weight"), (bmodel.fcLayers[3], "weight"), (bmodel.fcLayers[4], "weight"))
prune.global_unstructured(
    parameters_to_prune, pruning_method=util.ThresholdPruning, threshold=5
)

for child in bmodel.fcLayers:
    prune.remove(child, "weight")

tot = 0
size = 0
for g in bmodel.parameters():
    if(len(g.shape) > 1):
        print(g.shape)
        size += g.shape[0] * g.shape[1]
        r = torch.where(torch.eq(g, 0), 1., 0.)
        tot += torch.sum(r).item()
print(f"tot / size = {tot / size}")

print(bmodel.getAccuracy(test_loader, True, 5))

# %% [markdown]
# Salvataggio del modello binarizzato pruned

# %%
#util.save_model(bmodel, "./models/MnistNetworkPruned_binarized_model")

# %% [markdown]
# Caricamento del modello binarizzato pruned

# %%
import sys
sys.path.append("./utils/")
import utils.binarizedModel as binModel
import util
bmodel = binModel.MNISTBinarizedModel()
#util.load_model(bmodel, "./demo/models/mnist_pruned_84443_model")
util.load_model(bmodel, "./demo/models/mnist_pruned_96665_model")
output = bmodel.prediction(test_data[0][0].reshape(1, -1), pruned=True)

# %%
import sys
sys.path.append("./utils/")
import binarizedModel as binModel
import util
import mnistModel
model = mnistModel.MnistNetwork()
util.load_model(model, "./demo/models/mnist_model", device=device)
bmodel = binModel.MNISTBinarizedModel(device=device)
bmodel.trainModel(training_loader, test_loader, PATH="./demo/models/mnist_binarized_model")
# Out:
# epoch = 1/50, step = 100/600, loss = 0.5178994536399841
# epoch = 1/50, step = 200/600, loss = 0.24029308557510376
# epoch = 1/50, step = 300/600, loss = 0.27109551429748535
# epoch = 1/50, step = 400/600, loss = 0.27022162079811096
# epoch = 1/50, step = 500/600, loss = 0.30329039692878723
# epoch = 1/50, step = 600/600, loss = 0.3294365704059601
# Validation Accuracy = 80.66%
# epoch = 2/50, step = 100/600, loss = 0.2317800372838974
# epoch = 2/50, step = 200/600, loss = 0.1751854121685028
# epoch = 2/50, step = 300/600, loss = 0.24878264963626862
# epoch = 2/50, step = 400/600, loss = 0.1203133761882782
# epoch = 2/50, step = 500/600, loss = 0.09030026197433472
# epoch = 2/50, step = 600/600, loss = 0.180506631731987
# Validation Accuracy = 91.18%
# epoch = 3/50, step = 100/600, loss = 0.2352297157049179
# epoch = 3/50, step = 200/600, loss = 0.2625238001346588
# epoch = 3/50, step = 300/600, loss = 0.13193799555301666
# epoch = 3/50, step = 400/600, loss = 0.24102115631103516
# epoch = 3/50, step = 500/600, loss = 0.10724714398384094
# epoch = 3/50, step = 600/600, loss = 0.20892253518104553
# Validation Accuracy = 90.47%
# epoch = 4/50, step = 100/600, loss = 0.19928142428398132
# epoch = 4/50, step = 200/600, loss = 0.12041911482810974
# epoch = 4/50, step = 300/600, loss = 0.1524813026189804
# epoch = 4/50, step = 400/600, loss = 0.1257687509059906
# epoch = 4/50, step = 500/600, loss = 0.157902792096138
# epoch = 4/50, step = 600/600, loss = 0.11883893609046936
# Validation Accuracy = 93.48%
# epoch = 5/50, step = 100/600, loss = 0.1082003116607666
# epoch = 5/50, step = 200/600, loss = 0.20606257021427155
# epoch = 5/50, step = 300/600, loss = 0.28977712988853455
# epoch = 5/50, step = 400/600, loss = 0.28887948393821716
# epoch = 5/50, step = 500/600, loss = 0.09124410897493362
# epoch = 5/50, step = 600/600, loss = 0.06266535818576813
# Validation Accuracy = 93.23%
# epoch = 6/50, step = 100/600, loss = 0.05110931769013405
# epoch = 6/50, step = 200/600, loss = 0.18781022727489471
# epoch = 6/50, step = 300/600, loss = 0.10584636777639389
# epoch = 6/50, step = 400/600, loss = 0.04801640659570694
# epoch = 6/50, step = 500/600, loss = 0.04745226725935936
# epoch = 6/50, step = 600/600, loss = 0.11421827226877213
# Validation Accuracy = 94.94%
# epoch = 7/50, step = 100/600, loss = 0.1120559424161911
# epoch = 7/50, step = 200/600, loss = 0.05590013414621353
# epoch = 7/50, step = 300/600, loss = 0.11118649691343307
# epoch = 7/50, step = 400/600, loss = 0.032737914472818375
# epoch = 7/50, step = 500/600, loss = 0.07180426269769669
# epoch = 7/50, step = 600/600, loss = 0.20101313292980194
# Validation Accuracy = 93.54%
# epoch = 8/50, step = 100/600, loss = 0.1276577264070511
# epoch = 8/50, step = 200/600, loss = 0.07538726180791855
# epoch = 8/50, step = 300/600, loss = 0.11972185224294662
# epoch = 8/50, step = 400/600, loss = 0.09791397303342819
# epoch = 8/50, step = 500/600, loss = 0.17519724369049072
# epoch = 8/50, step = 600/600, loss = 0.14028789103031158
# Validation Accuracy = 93.75%
# epoch = 9/50, step = 100/600, loss = 0.08082883059978485
# epoch = 9/50, step = 200/600, loss = 0.06255146861076355
# epoch = 9/50, step = 300/600, loss = 0.04368915036320686
# epoch = 9/50, step = 400/600, loss = 0.11555805802345276
# epoch = 9/50, step = 500/600, loss = 0.15198887884616852
# epoch = 9/50, step = 600/600, loss = 0.08806688338518143
# Validation Accuracy = 95.31%
# epoch = 10/50, step = 100/600, loss = 0.07758713513612747
# epoch = 10/50, step = 200/600, loss = 0.318663626909256
# epoch = 10/50, step = 300/600, loss = 0.19618314504623413
# epoch = 10/50, step = 400/600, loss = 0.11760710924863815
# epoch = 10/50, step = 500/600, loss = 0.26494354009628296
# epoch = 10/50, step = 600/600, loss = 0.09080058336257935
# Validation Accuracy = 94.82%
# epoch = 11/50, step = 100/600, loss = 0.06919237971305847
# epoch = 11/50, step = 200/600, loss = 0.11628281325101852
# epoch = 11/50, step = 300/600, loss = 0.10734619945287704
# epoch = 11/50, step = 400/600, loss = 0.1777377724647522
# epoch = 11/50, step = 500/600, loss = 0.1057765856385231
# epoch = 11/50, step = 600/600, loss = 0.06526470929384232
# Validation Accuracy = 94.78%
# epoch = 12/50, step = 100/600, loss = 0.05924079567193985
# epoch = 12/50, step = 200/600, loss = 0.033006615936756134
# epoch = 12/50, step = 300/600, loss = 0.20663855969905853
# epoch = 12/50, step = 400/600, loss = 0.13425792753696442
# epoch = 12/50, step = 500/600, loss = 0.11783641576766968
# epoch = 12/50, step = 600/600, loss = 0.1595914363861084
# Validation Accuracy = 95.32%
# epoch = 13/50, step = 100/600, loss = 0.12377858906984329
# epoch = 13/50, step = 200/600, loss = 0.1970595121383667
# epoch = 13/50, step = 300/600, loss = 0.06004408746957779
# epoch = 13/50, step = 400/600, loss = 0.02295888401567936
# epoch = 13/50, step = 500/600, loss = 0.11324227601289749
# epoch = 13/50, step = 600/600, loss = 0.04177624359726906
# Validation Accuracy = 95.3%
# epoch = 14/50, step = 100/600, loss = 0.14682088792324066
# epoch = 14/50, step = 200/600, loss = 0.029098255559802055
# epoch = 14/50, step = 300/600, loss = 0.24389337003231049
# epoch = 14/50, step = 400/600, loss = 0.09056302905082703
# epoch = 14/50, step = 500/600, loss = 0.031707197427749634
# epoch = 14/50, step = 600/600, loss = 0.09750856459140778
# Validation Accuracy = 96.09%
# epoch = 15/50, step = 100/600, loss = 0.02185767889022827
# epoch = 15/50, step = 200/600, loss = 0.1071917787194252
# epoch = 15/50, step = 300/600, loss = 0.030930809676647186
# epoch = 15/50, step = 400/600, loss = 0.03601689636707306
# epoch = 15/50, step = 500/600, loss = 0.08502810448408127
# epoch = 15/50, step = 600/600, loss = 0.0931895449757576
# Validation Accuracy = 95.71%
# epoch = 16/50, step = 100/600, loss = 0.03390555456280708
# epoch = 16/50, step = 200/600, loss = 0.032099660485982895
# epoch = 16/50, step = 300/600, loss = 0.05589284375309944
# epoch = 16/50, step = 400/600, loss = 0.040840715169906616
# epoch = 16/50, step = 500/600, loss = 0.0159300584346056
# epoch = 16/50, step = 600/600, loss = 0.012691598385572433
# Validation Accuracy = 95.94%
# epoch = 17/50, step = 100/600, loss = 0.0964183434844017
# epoch = 17/50, step = 200/600, loss = 0.05418653413653374
# epoch = 17/50, step = 300/600, loss = 0.04228467121720314
# epoch = 17/50, step = 400/600, loss = 0.09760846942663193
# epoch = 17/50, step = 500/600, loss = 0.12130574136972427
# epoch = 17/50, step = 600/600, loss = 0.137250617146492
# Validation Accuracy = 95.99%
# epoch = 18/50, step = 100/600, loss = 0.007664041593670845
# epoch = 18/50, step = 200/600, loss = 0.03024124912917614
# epoch = 18/50, step = 300/600, loss = 0.03370845317840576
# epoch = 18/50, step = 400/600, loss = 0.06856312602758408
# epoch = 18/50, step = 500/600, loss = 0.09851367771625519
# epoch = 18/50, step = 600/600, loss = 0.055532604455947876
# Validation Accuracy = 95.82%
# epoch = 19/50, step = 100/600, loss = 0.019631851464509964
# epoch = 19/50, step = 200/600, loss = 0.021943770349025726
# epoch = 19/50, step = 300/600, loss = 0.03350437805056572
# epoch = 19/50, step = 400/600, loss = 0.12471380829811096
# epoch = 19/50, step = 500/600, loss = 0.08928970992565155
# epoch = 19/50, step = 600/600, loss = 0.1007450520992279
# Validation Accuracy = 95.9%
# epoch = 20/50, step = 100/600, loss = 0.040526408702135086
# epoch = 20/50, step = 200/600, loss = 0.06265711784362793
# epoch = 20/50, step = 300/600, loss = 0.04139985144138336
# epoch = 20/50, step = 400/600, loss = 0.04571785405278206
# epoch = 20/50, step = 500/600, loss = 0.0756145566701889
# epoch = 20/50, step = 600/600, loss = 0.021170292049646378
# Validation Accuracy = 94.81%
# epoch = 21/50, step = 100/600, loss = 0.02326183021068573
# epoch = 21/50, step = 200/600, loss = 0.012488246895372868
# epoch = 21/50, step = 300/600, loss = 0.05188633129000664
# epoch = 21/50, step = 400/600, loss = 0.019493483006954193
# epoch = 21/50, step = 500/600, loss = 0.04223986715078354
# epoch = 21/50, step = 600/600, loss = 0.10662078112363815
# Validation Accuracy = 96.09%
# epoch = 22/50, step = 100/600, loss = 0.0401301272213459
# epoch = 22/50, step = 200/600, loss = 0.08924049139022827
# epoch = 22/50, step = 300/600, loss = 0.014787737280130386
# epoch = 22/50, step = 400/600, loss = 0.022990500554442406
# epoch = 22/50, step = 500/600, loss = 0.07433951646089554
# epoch = 22/50, step = 600/600, loss = 0.06286537647247314
# Validation Accuracy = 96.28%
# epoch = 23/50, step = 100/600, loss = 0.02539968304336071
# epoch = 23/50, step = 200/600, loss = 0.08022579550743103
# epoch = 23/50, step = 300/600, loss = 0.032286614179611206
# epoch = 23/50, step = 400/600, loss = 0.02913702093064785
# epoch = 23/50, step = 500/600, loss = 0.13795801997184753
# epoch = 23/50, step = 600/600, loss = 0.0411217100918293
# Validation Accuracy = 96.1%
# epoch = 24/50, step = 100/600, loss = 0.02599538490176201
# epoch = 24/50, step = 200/600, loss = 0.014447090215981007
# epoch = 24/50, step = 300/600, loss = 0.014096004888415337
# epoch = 24/50, step = 400/600, loss = 0.03580331429839134
# epoch = 24/50, step = 500/600, loss = 0.06675010919570923
# epoch = 24/50, step = 600/600, loss = 0.11272378265857697
# Validation Accuracy = 95.86%
# epoch = 25/50, step = 100/600, loss = 0.030340634286403656
# epoch = 25/50, step = 200/600, loss = 0.08094310760498047
# epoch = 25/50, step = 300/600, loss = 0.05807029828429222
# epoch = 25/50, step = 400/600, loss = 0.035691067576408386
# epoch = 25/50, step = 500/600, loss = 0.04414540156722069
# epoch = 25/50, step = 600/600, loss = 0.02004069834947586
# Validation Accuracy = 96.14%
# epoch = 26/50, step = 100/600, loss = 0.0050903004594147205
# epoch = 26/50, step = 200/600, loss = 0.06090026721358299
# epoch = 26/50, step = 300/600, loss = 0.0183425210416317
# epoch = 26/50, step = 400/600, loss = 0.026402408257126808
# epoch = 26/50, step = 500/600, loss = 0.04723995178937912
# epoch = 26/50, step = 600/600, loss = 0.10743775218725204
# Validation Accuracy = 95.66%
# epoch = 27/50, step = 100/600, loss = 0.058867570012807846
# epoch = 27/50, step = 200/600, loss = 0.13739249110221863
# epoch = 27/50, step = 300/600, loss = 0.03125786781311035
# epoch = 27/50, step = 400/600, loss = 0.006957824807614088
# epoch = 27/50, step = 500/600, loss = 0.01871420256793499
# epoch = 27/50, step = 600/600, loss = 0.014380727894604206
# Validation Accuracy = 96.56%
# epoch = 28/50, step = 100/600, loss = 0.01289365440607071
# epoch = 28/50, step = 200/600, loss = 0.02827170304954052
# epoch = 28/50, step = 300/600, loss = 0.022088443860411644
# epoch = 28/50, step = 400/600, loss = 0.14863815903663635
# epoch = 28/50, step = 500/600, loss = 0.09884867072105408
# epoch = 28/50, step = 600/600, loss = 0.04298515245318413
# Validation Accuracy = 96.0%
# epoch = 29/50, step = 100/600, loss = 0.007031066808849573
# epoch = 29/50, step = 200/600, loss = 0.009254314005374908
# epoch = 29/50, step = 300/600, loss = 0.018276328220963478
# epoch = 29/50, step = 400/600, loss = 0.05570429190993309
# epoch = 29/50, step = 500/600, loss = 0.01366148516535759
# epoch = 29/50, step = 600/600, loss = 0.046465665102005005
# Validation Accuracy = 96.52%
# epoch = 30/50, step = 100/600, loss = 0.05416183918714523
# epoch = 30/50, step = 200/600, loss = 0.05538621544837952
# epoch = 30/50, step = 300/600, loss = 0.12325248122215271
# epoch = 30/50, step = 400/600, loss = 0.002872065408155322
# epoch = 30/50, step = 500/600, loss = 0.01709575206041336
# epoch = 30/50, step = 600/600, loss = 0.015835560858249664
# Validation Accuracy = 96.43%
# epoch = 31/50, step = 100/600, loss = 0.003035226371139288
# epoch = 31/50, step = 200/600, loss = 0.019138192757964134
# epoch = 31/50, step = 300/600, loss = 0.08200474828481674
# epoch = 31/50, step = 400/600, loss = 0.06340275704860687
# epoch = 31/50, step = 500/600, loss = 0.012076170183718204
# epoch = 31/50, step = 600/600, loss = 0.02321580797433853
# Validation Accuracy = 95.86%
# epoch = 32/50, step = 100/600, loss = 0.14053435623645782
# epoch = 32/50, step = 200/600, loss = 0.022155113518238068
# epoch = 32/50, step = 300/600, loss = 0.01692940667271614
# epoch = 32/50, step = 400/600, loss = 0.01255524717271328
# epoch = 32/50, step = 500/600, loss = 0.08277773857116699
# epoch = 32/50, step = 600/600, loss = 0.07089558988809586
# Validation Accuracy = 95.76%
# epoch = 33/50, step = 100/600, loss = 0.002219238318502903
# epoch = 33/50, step = 200/600, loss = 0.00245629227720201
# epoch = 33/50, step = 300/600, loss = 0.015445824712514877
# epoch = 33/50, step = 400/600, loss = 0.046362608671188354
# epoch = 33/50, step = 500/600, loss = 0.07475294172763824
# epoch = 33/50, step = 600/600, loss = 0.08746328949928284
# Validation Accuracy = 96.78%
# epoch = 34/50, step = 100/600, loss = 0.04757098853588104
# epoch = 34/50, step = 200/600, loss = 0.05808504670858383
# epoch = 34/50, step = 300/600, loss = 0.0455319844186306
# epoch = 34/50, step = 400/600, loss = 0.06902119517326355
# epoch = 34/50, step = 500/600, loss = 0.1827729344367981
# epoch = 34/50, step = 600/600, loss = 0.010706278495490551
# Validation Accuracy = 96.43%
# epoch = 35/50, step = 100/600, loss = 0.014316448010504246
# epoch = 35/50, step = 200/600, loss = 0.03547411784529686
# epoch = 35/50, step = 300/600, loss = 0.05232008919119835
# epoch = 35/50, step = 400/600, loss = 0.021209290251135826
# epoch = 35/50, step = 500/600, loss = 0.002725588157773018
# epoch = 35/50, step = 600/600, loss = 0.050720974802970886
# Validation Accuracy = 96.63%
# epoch = 36/50, step = 100/600, loss = 0.025011444464325905
# epoch = 36/50, step = 200/600, loss = 0.009495522826910019
# epoch = 36/50, step = 300/600, loss = 0.09617391228675842
# epoch = 36/50, step = 400/600, loss = 0.005309573840349913
# epoch = 36/50, step = 500/600, loss = 0.013762558810412884
# epoch = 36/50, step = 600/600, loss = 0.09203468263149261
# Validation Accuracy = 96.5%
# epoch = 37/50, step = 100/600, loss = 0.005335779394954443
# epoch = 37/50, step = 200/600, loss = 0.04861966520547867
# epoch = 37/50, step = 300/600, loss = 0.030310284346342087
# epoch = 37/50, step = 400/600, loss = 0.016478119418025017
# epoch = 37/50, step = 500/600, loss = 0.07401850074529648
# epoch = 37/50, step = 600/600, loss = 0.007886647246778011
# Validation Accuracy = 96.7%
# epoch = 38/50, step = 100/600, loss = 0.017840463668107986
# epoch = 38/50, step = 200/600, loss = 0.016933294013142586
# epoch = 38/50, step = 300/600, loss = 0.004344714339822531
# epoch = 38/50, step = 400/600, loss = 0.029347725212574005
# epoch = 38/50, step = 500/600, loss = 0.05001819506287575
# epoch = 38/50, step = 600/600, loss = 0.05686534568667412
# Validation Accuracy = 96.44%
# epoch = 39/50, step = 100/600, loss = 0.020220287144184113
# epoch = 39/50, step = 200/600, loss = 0.041164331138134
# epoch = 39/50, step = 300/600, loss = 0.06106526777148247
# epoch = 39/50, step = 400/600, loss = 0.0628240630030632
# epoch = 39/50, step = 500/600, loss = 0.05087215453386307
# epoch = 39/50, step = 600/600, loss = 0.0010938789928331971
# Validation Accuracy = 96.55%
# epoch = 40/50, step = 100/600, loss = 0.004460303578525782
# epoch = 40/50, step = 200/600, loss = 0.007048053201287985
# epoch = 40/50, step = 300/600, loss = 0.020355558022856712
# epoch = 40/50, step = 400/600, loss = 0.04885218292474747
# epoch = 40/50, step = 500/600, loss = 0.05811303108930588
# epoch = 40/50, step = 600/600, loss = 0.029109420254826546
# Validation Accuracy = 96.82%
# epoch = 41/50, step = 100/600, loss = 0.007158010732382536
# epoch = 41/50, step = 200/600, loss = 0.007246536668390036
# epoch = 41/50, step = 300/600, loss = 0.014187157154083252
# epoch = 41/50, step = 400/600, loss = 0.010289216414093971
# epoch = 41/50, step = 500/600, loss = 0.0017897129291668534
# epoch = 41/50, step = 600/600, loss = 0.11712732911109924
# Validation Accuracy = 96.71%
# epoch = 42/50, step = 100/600, loss = 0.022261111065745354
# epoch = 42/50, step = 200/600, loss = 0.03856976702809334
# epoch = 42/50, step = 300/600, loss = 0.014261770062148571
# epoch = 42/50, step = 400/600, loss = 0.01047975942492485
# epoch = 42/50, step = 500/600, loss = 0.026858408004045486
# epoch = 42/50, step = 600/600, loss = 0.007140898145735264
# Validation Accuracy = 96.89%
# epoch = 43/50, step = 100/600, loss = 0.01622345857322216
# epoch = 43/50, step = 200/600, loss = 0.041454464197158813
# epoch = 43/50, step = 300/600, loss = 0.013968652114272118
# epoch = 43/50, step = 400/600, loss = 0.0009477157727815211
# epoch = 43/50, step = 500/600, loss = 0.01888447441160679
# epoch = 43/50, step = 600/600, loss = 0.02261952869594097
# Validation Accuracy = 96.73%
# epoch = 44/50, step = 100/600, loss = 0.0950140580534935
# epoch = 44/50, step = 200/600, loss = 0.0020266713108867407
# epoch = 44/50, step = 300/600, loss = 0.05008354038000107
# epoch = 44/50, step = 400/600, loss = 0.07262901216745377
# epoch = 44/50, step = 500/600, loss = 0.1314437836408615
# epoch = 44/50, step = 600/600, loss = 0.010683996602892876
# Validation Accuracy = 96.69%
# epoch = 45/50, step = 100/600, loss = 0.04322659596800804
# epoch = 45/50, step = 200/600, loss = 0.022456670179963112
# epoch = 45/50, step = 300/600, loss = 0.0011591394431889057
# epoch = 45/50, step = 400/600, loss = 0.07200335711240768
# epoch = 45/50, step = 500/600, loss = 0.00412400346249342
# epoch = 45/50, step = 600/600, loss = 0.023830249905586243
# Validation Accuracy = 96.68%
# epoch = 46/50, step = 100/600, loss = 0.016787845641374588
# epoch = 46/50, step = 200/600, loss = 0.017229359596967697
# epoch = 46/50, step = 300/600, loss = 0.005794708151370287
# epoch = 46/50, step = 400/600, loss = 0.10162477195262909
# epoch = 46/50, step = 500/600, loss = 0.013770818710327148
# epoch = 46/50, step = 600/600, loss = 0.006102427840232849
# Validation Accuracy = 96.82%
# epoch = 47/50, step = 100/600, loss = 0.014806041494011879
# epoch = 47/50, step = 200/600, loss = 0.03928535804152489
# epoch = 47/50, step = 300/600, loss = 0.007013881579041481
# epoch = 47/50, step = 400/600, loss = 0.013077396899461746
# epoch = 47/50, step = 500/600, loss = 0.006051072850823402
# epoch = 47/50, step = 600/600, loss = 0.06387834995985031
# Validation Accuracy = 96.41%
# epoch = 48/50, step = 100/600, loss = 0.004561292938888073
# epoch = 48/50, step = 200/600, loss = 0.04790914058685303
# epoch = 48/50, step = 300/600, loss = 0.07661692798137665
# epoch = 48/50, step = 400/600, loss = 0.011881612241268158
# epoch = 48/50, step = 500/600, loss = 0.007947392761707306
# epoch = 48/50, step = 600/600, loss = 0.07974376529455185
# Validation Accuracy = 96.97%
# epoch = 49/50, step = 100/600, loss = 0.017110643908381462
# epoch = 49/50, step = 200/600, loss = 0.036003731191158295
# epoch = 49/50, step = 300/600, loss = 0.012762441299855709
# epoch = 49/50, step = 400/600, loss = 0.0339839868247509
# epoch = 49/50, step = 500/600, loss = 0.008024311624467373
# epoch = 49/50, step = 600/600, loss = 0.010474877431988716
# Validation Accuracy = 96.86%
# epoch = 50/50, step = 100/600, loss = 0.05749242752790451
# epoch = 50/50, step = 200/600, loss = 0.0627816841006279
# epoch = 50/50, step = 300/600, loss = 0.007217011880129576
# epoch = 50/50, step = 400/600, loss = 0.015165622346103191
# epoch = 50/50, step = 500/600, loss = 0.006009930744767189
# epoch = 50/50, step = 600/600, loss = 0.042478565126657486
# Validation Accuracy = 96.79%
